# %% [markdown]
# <a href="https://colab.research.google.com/github/PranaliIthule/DSA-Python-Training/blob/main/DSA_DAY_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

class Graphs:
    def __init__(self):
        self.graph = {}

    def addNode(self):
        node = input("Enter node: ")

        if node not in self.graph:
            self.graph[node] = []
            print("Node Added")
        else:
            print("Node already exists")

    def addEdge_Undirected_Unweighted(self):
        u = input("Enter first node: ")
        v = input("Enter second node: ")

        if u in self.graph and v in self.graph:
            self.graph[u].append(v)
            self.graph[v].append(u)
            print("Edge Added")
        else:
            print("Node not found")

    def addEdge_Undirected_Weighted(self):
        u = input("Enter first node: ")
        v = input("Enter second node: ")
        w = int(input("Enter weight: "))

        if u in self.graph and v in self.graph:
            self.graph[u].append((v, w))
            self.graph[v].append((u, w))
            print("Weighted Edge Added")
        else:
            print("Node not found")

    def addEdge_Directed_Weighted(self):
        u = input("Enter source node: ")
        v = input("Enter destination node: ")
        w = int(input("Enter weight: "))

        if u in self.graph and v in self.graph:
            self.graph[u].append((v, w))
            print("Directed Weighted Edge Added")
        else:
            print("Node not found")

    def printGraph(self):
        print("\nGraph:")
        for i in self.graph:
            print(i, "->", self.graph[i])

    def deleteGraph(self):
        self.graph.clear()
        print("Graph Deleted")


if __name__ == '__main__':
    obj = Graphs()

    while True:
        print("\n1. (Insertion) Add a node using adjacency matrix representation")
        print("2. (Insertion) Add an edge using adjacency matrix representation")
        print("3. (Insertion) Add an edge undirected weighted graph")
        print("4. (Insertion) Add an edge directed weighted graph")
        print("5. Print Graph")
        print("6. Delete Operation")
        print("0. Exit\n")

        n = int(input("Enter any choice: "))

        if n == 1:
            obj.addNode()

        elif n == 2:
            obj.addEdge_Undirected_Unweighted()

        elif n == 3:
            obj.addEdge_Undirected_Weighted()

        elif n == 4:
            obj.addEdge_Directed_Weighted()

        elif n == 5:
            obj.printGraph()

        elif n == 6:
            obj.deleteGraph()

        elif n == 0:
            sys.exit(0)

        else:
            print("Invalid Choice")
# Out:
# 1. (Insertion) Add a node using adjacency matrix representation
# 2. (Insertion) Add an edge using adjacency matrix representation
# 3. (Insertion) Add an edge undirected weighted graph
# 4. (Insertion) Add an edge directed weighted graph
# 5. Print Graph
# 6. Delete Operation
# 0. Exit
#
# Enter any choice: 1
# Enter node: 23
# Node Added
#
# 1. (Insertion) Add a node using adjacency matrix representation
# 2. (Insertion) Add an edge using adjacency matrix representation
# 3. (Insertion) Add an edge undirected weighted graph
# 4. (Insertion) Add an edge directed weighted graph
# 5. Print Graph
# 6. Delete Operation
# 0. Exit
#
# Enter any choice: 2
# Enter first node: 21
# Enter second node: 22
# Node not found
#
# 1. (Insertion) Add a node using adjacency matrix representation
# 2. (Insertion) Add an edge using adjacency matrix representation
# 3. (Insertion) Add an edge undirected weighted graph
# 4. (Insertion) Add an edge directed weighted graph
# 5. Print Graph
# 6. Delete Operation
# 0. Exit
#
# Enter any choice: 3
# Enter first node: 24
# Enter second node: 25
# Enter weight: 3
# Node not found
#
# 1. (Insertion) Add a node using adjacency matrix representation
# 2. (Insertion) Add an edge using adjacency matrix representation
# 3. (Insertion) Add an edge undirected weighted graph
# 4. (Insertion) Add an edge directed weighted graph
# 5. Print Graph
# 6. Delete Operation
# 0. Exit
#
# Enter any choice: 5
#
# Graph:
# 23 -> []
#
# 1. (Insertion) Add a node using adjacency matrix representation
# 2. (Insertion) Add an edge using adjacency matrix representation
# 3. (Insertion) Add an edge undirected weighted graph
# 4. (Insertion) Add an edge directed weighted graph
# 5. Print Graph
# 6. Delete Operation
# 0. Exit
#
# Enter any choice: 0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#GRAPH
import sys
class Graphs:
    def _init_(self):
      self.nodes=[]
      self.graphs=[]
      self.nodeCount=0

    def addNode(self,v):
      if v in self.nodes:
        print(v,"node already exist")
      else:
        self.nodeCount+=1
        self.nodes.append(v)
        for  x in self.graphs:
          x.append(0)
        temp=[]
        for x in range(self.nodeCount):
          temp.append(0) #temp[]=0
        self.graphs.append(temp)
        print(v," is added")


    def addEdge_directed_weighted(self):
      pass
    def addEdge_Undirected_Unweighted(self):
      pass
    def addEdge_Undirected_weighted(self):
      pass
    def addEdge_Undirected_weighted(self):
      pass

    def printGraph(self):
      print(*self.nodes)
      for i in range(self.nodeCount):
        for j in range(self.nodeCount):
          print(self.graphs[i][j],end=" ")
        print("")
    def deletGraph(self):
      pass
if _name=="main_":
  obj=Graphs()
  while True:
    print("\n1. (insertion) add a node using adjacency matrix representation");
    print("2. (insertion) add an edge using adjacency matrix representation");
    print("3. (insertion)add a edge undirected weighted graph");
    print("4. (insertion) add a edge directed weighted graph");
    print("5. print graph");
    print("6. delet operation");
    print("7. exit");
    n=int(input("enter any choice: "))
    if n==1:
      v=input("enter vertex")
      obj.addNode(v)
    elif n==2:
      obj.addEdge_Undirected_Unweighted()
    elif n==3:
      obj.addEdge_Undirected_weighted()
    elif n==4:
      obj.addEdge_directed_weighted()
    elif n==5:
      obj.printGraph()
    elif n==6:
      obj.deletGraph()
    elif n==0:
      sys.exit(0)
    else:
      print("invalid choice")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1198/289573373.py in <cell line: 0>()
#      39     def deletGraph(self):
#      40       pass
# ---> 41 if _name=="main_":
#      42   obj=Graphs()
#      43   while True:
#
# NameError: name '_name' is not defined

# %%
#GRAPH
import sys
class Graphs:
    def __init__(self):
      self.nodes=[]
      self.graphs=[]
      self.nodeCount=0

    def addNode(self,v):
      if v in self.nodes:
        print(v,"node already exist")
      else:
        self.nodeCount+=1
        self.nodes.append(v)
        for x in self.graphs:
          x.append(0)
        temp=[]
        for x in range(self.nodeCount):
          temp.append(0) #temp[]=0
        self.graphs.append(temp)
        print(v," is added")


    def addEdge_directed_weighted(self):
      pass

    def addEdge_Undirected_Unweighted(self):
      pass

    def addEdge_Undirected_weighted(self):
      pass

    def addEdge_Undirected_weighted(self):
      pass

    def printGraph(self):
      print(*self.nodes)
      for i in range(self.nodeCount):
        for j in range(self.nodeCount):
          print(self.graphs[i][j],end=" ")
        print("")

    def deletGraph(self):
      pass

if __name__=="__main__":
  obj=Graphs()

  while True:

    print("\n1. (insertion) add a node using adjacency matrix representation")
    print("2. (insertion) add an edge using adjacency matrix representation")
    print("3. (insertion)add a edge undirected weighted graph")
    print("4. (insertion) add a edge directed weighted graph")
    print("5. print graph")
    print("6. delet operation")
    print("0. exit")

    n=int(input("enter any choice: "))

    if n==1:
      v=input("enter vertex")
      obj.addNode(v)

    elif n==2:
      obj.addEdge_Undirected_Unweighted()

    elif n==3:
      obj.addEdge_Undirected_weighted()

    elif n==4:
      obj.addEdge_directed_weighted()

    elif n==5:
      obj.printGraph()

    elif n==6:
      obj.deletGraph()

    elif n==0:
      sys.exit(0)

    else:
      print("invalid choice")
# Out:
# 1. (insertion) add a node using adjacency matrix representation
# 2. (insertion) add an edge using adjacency matrix representation
# 3. (insertion)add a edge undirected weighted graph
# 4. (insertion) add a edge directed weighted graph
# 5. print graph
# 6. delet operation
# 0. exit
# 33  is added
#
# 1. (insertion) add a node using adjacency matrix representation
# 2. (insertion) add an edge using adjacency matrix representation
# 3. (insertion)add a edge undirected weighted graph
# 4. (insertion) add a edge directed weighted graph
# 5. print graph
# 6. delet operation
# 0. exit
# 33
# 0
#
# 1. (insertion) add a node using adjacency matrix representation
# 2. (insertion) add an edge using adjacency matrix representation
# 3. (insertion)add a edge undirected weighted graph
# 4. (insertion) add a edge directed weighted graph
# 5. print graph
# 6. delet operation
# 0. exit
#
# 1. (insertion) add a node using adjacency matrix representation
# 2. (insertion) add an edge using adjacency matrix representation
# 3. (insertion)add a edge undirected weighted graph
# 4. (insertion) add a edge directed weighted graph
# 5. print graph
# 6. delet operation
# 0. exit

# %%
print(v, "is added")

def addEdge_Undirected_Unweighted(self, v1, v2):
    if v1 not in self.nodes:
        print(v1, "not present")
        return
    if v2 not in self.nodes:
        print(v2, "not present")
        return
    index1 = self.nodes.index(v1)
    index2 = self.nodes.index(v2)
    self.graph[index1][index2] = 1
    self.graph[index2][index1] = 1

def addEdge_Undirected_Weighted(self):
    pass

def addEdge_Directed_Weighted(self):
    pass

# %%
import sys
class Graphs:
    def _init_(self):
      self.nodes=[]
      self.graphs=[]
      self.nodeCount=0

    def addNode(self,v):
      if v in self.nodes:
        print(v,"node already exist")
      else:
        self.nodeCount+=1
        self.nodes.append(v)
        for x in self.graphs:
          x.append(0)
        temp=[]
        for x in range(self.nodeCount):
          temp.append(0) #temp[]=0
        self.graphs.append(temp)
        print(v," is added")


    def addEdge_directed_weighted(self):
      pass

    def addEdge_Undirected_Unweighted(self):
      pass

    def addEdge_Undirected_weighted(self):
      pass

    def addEdge_Undirected_weighted(self):
      pass

    def printGraph(self):
      print(*self.nodes)
      for i in range(self.nodeCount):
        for j in range(self.nodeCount):
          print(self.graphs[i][j],end=" ")
        print("")

    def deletGraph(self):
      pass

if _name=="main_":
  obj=Graphs()

  while True:

    print("\n1. (insertion) add a node using adjacency matrix representation")
    print("2. (insertion) add an edge using adjacency matrix representation")
    print("3. (insertion)add a edge undirected weighted graph")
    print("4. (insertion) add a edge directed weighted graph")
    print("5. print graph")
    print("6. delet operation")
    print("0. exit")

    n=int(input("enter any choice: "))

    if n==1:
      v=input("enter vertex")
      obj.addNode(v)

    elif n==2:
      obj.addEdge_Undirected_Unweighted()

    elif n==3:
      obj.addEdge_Undirected_weighted()

    elif n==4:
      obj.addEdge_directed_weighted()

    elif n==5:
      obj.printGraph()

    elif n==6:
      obj.deletGraph()

    elif n==0:
      sys.exit(0)

    else:
      print("invalid choice")

# %%
import sys
class Graphs:
    def __init__(self):
        self.nodes = []
        self.graphs = []
        self.nodeCount = 0

    def addNode(self, v):
        if v in self.nodes:
            print(v, "node already exists")
        else:
            self.nodeCount += 1
            self.nodes.append(v)

            for x in self.graphs:
                x.append(0)

            temp = []
            for x in range(self.nodeCount):
                temp.append(0)

            self.graphs.append(temp)
            print(v, "is added")

    def addEdge_Undirected_Unweighted(self):
        v1 = input("Enter first vertex: ")
        v2 = input("Enter second vertex: ")

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")
        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = 1
            self.graphs[index2][index1] = 1

            print("Edge added successfully")

    def addEdge_directed_weighted(self):
        v1 = input("Enter source vertex: ")
        v2 = input("Enter destination vertex: ")
        w = int(input("Enter weight: "))

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")
        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = w

            print("Directed weighted edge added")

    def addEdge_Undirected_weighted(self):
        v1 = input("Enter first vertex: ")
        v2 = input("Enter second vertex: ")
        w = int(input("Enter weight: "))

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")
        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = w
            self.graphs[index2][index1] = w

            print("Undirected weighted edge added")

    def deletGraph(self):
        self.nodes.clear()
        self.graphs.clear()
        self.nodeCount = 0

        print("Graph deleted successfully")

    def printGraph(self):
        print("\nAdjacency Matrix:")

        print("   ", end="")
        for node in self.nodes:
            print(node, end=" ")
        print()

        for i in range(self.nodeCount):
            print(self.nodes[i], end="  ")
            for j in range(self.nodeCount):
                print(self.graphs[i][j], end=" ")
            print()


if __name__ == "__main__":

    obj = Graphs()

    while True:

        print("\n========== GRAPH MENU ==========")
        print("1. Add Node")
        print("2. Add Edge (Undirected Unweighted)")
        print("3. Add Edge (Undirected Weighted)")
        print("4. Add Edge (Directed Weighted)")
        print("5. Print Graph")
        print("6. Delete Graph")
        print("0. Exit")

        n = int(input("Enter your choice: "))

        if n == 1:
            v = input("Enter vertex: ")
            obj.addNode(v)

        elif n == 2:
            obj.addEdge_Undirected_Unweighted()

        elif n == 3:
            obj.addEdge_Undirected_weighted()

        elif n == 4:
            obj.addEdge_directed_weighted()

        elif n == 5:
            obj.printGraph()

        elif n == 6:
            obj.deletGraph()

        elif n == 0:
            print("Program terminated")
            sys.exit(0)

        else:
            print("Invalid choice")
# Out:
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Graph
# 0. Exit
# Enter your choice: 2
# Enter first vertex: 2
# Enter second vertex: 4
# One or both vertices not found
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Graph
# 0. Exit
# Enter your choice: 1
# Enter vertex: 2
# 2 is added
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Graph
# 0. Exit
# Enter your choice: 4
# Enter source vertex: 3
# Enter destination vertex: 5
# Enter weight: 3
# One or both vertices not found
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Graph
# 0. Exit
# Enter your choice: 2
# Enter first vertex: 1
# Enter second vertex: 3
# One or both vertices not found
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Graph
# 0. Exit
# Enter your choice: 2
# Enter first vertex: 2
# Enter second vertex: 4
# One or both vertices not found
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Graph
# 0. Exit
# Enter your choice: 5
#
# Adjacency Matrix:
#    2
# 2  0
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Graph
# 0. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9054/430300932.py in <cell line: 0>()
#     106         print("0. Exit")
#     107
# --> 108         n = int(input("Enter your choice: "))
#     109
#     110         if n == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
s = input("Enter String : ")

count = 1
result = ""

for i in range(len(s)-1):

    if s[i] == s[i+1]:
        count += 1

    else:
        result = result + s[i] + str(count)
        count = 1

result = result + s[len(s)-1] + str(count)

print(result)

# %%
s = input("Enter String : ")

count = 1
result = ""

for i in range(len(s)-1):

    if s[i] == s[i+1]:
        count = count + 1

    else:
        result = result + s[i] + str(count)
        count = 1

result = result + s[-1] + str(count)

print(result)
# Out:
# Enter String : aabbbbeeeeffggg
# a2b4e4f2g3

# %%
def deleteGraph(self,v):
  if v not in self.nodes:
    print(v,"not present")
  else:
      nodeCount-=1
      index1=self.nodes.index(v)
      self.nodes.pop(index1)
      self.graph.pop(index1)
      for x in self.self.graph:
        x.pop(index1)
        print("v,deleted")

# %%
import sys
class Graphs:
    def __init__(self):
        self.nodes = []
        self.graphs = []
        self.nodeCount = 0

    def addNode(self, v):
        if v in self.nodes:
            print(v, "node already exists")
        else:
            self.nodeCount += 1
            self.nodes.append(v)

            for x in self.graphs:
                x.append(0)

            temp = []
            for x in range(self.nodeCount):
                temp.append(0)

            self.graphs.append(temp)
            print(v, "is added")

    def addEdge_Undirected_Unweighted(self):
        v1 = input("Enter first vertex: ")
        v2 = input("Enter second vertex: ")

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")
        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = 1
            self.graphs[index2][index1] = 1

            print("Edge added successfully")

    def addEdge_directed_weighted(self):
        v1 = input("Enter source vertex: ")
        v2 = input("Enter destination vertex: ")
        w = int(input("Enter weight: "))

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")
        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = w

            print("Directed weighted edge added")

    def addEdge_Undirected_weighted(self):
        v1 = input("Enter first vertex: ")
        v2 = input("Enter second vertex: ")
        w = int(input("Enter weight: "))

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")
        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = w
            self.graphs[index2][index1] = w

            print("Undirected weighted edge added")

    def deleteGraph(self,v):
  if v not in self.nodes:
    print(v,"not present")
  else:
      nodeCount-=1
      index1=self.nodes.index(v)
      self.nodes.pop(index1)
      self.graph.pop(index1)
      for x in self.self.graph:
        x.pop(index1)
        print("v,deleted")
    def printGraph(self):
        print("\nAdjacency Matrix:")

        print("   ", end="")
        for node in self.nodes:
            print(node, end=" ")
        print()

        for i in range(self.nodeCount):
            print(self.nodes[i], end="  ")
            for j in range(self.nodeCount):
                print(self.graphs[i][j], end=" ")
            print()


if __name__ == "__main__":

    obj = Graphs()

    while True:

        print("\n========== GRAPH MENU ==========")
        print("1. Add Node")
        print("2. Add Edge (Undirected Unweighted)")
        print("3. Add Edge (Undirected Weighted)")
        print("4. Add Edge (Directed Weighted)")
        print("5. Print Graph")
        print("6. Delete Graph")
        print("0. Exit")

        n = int(input("Enter your choice: "))

        if n == 1:
            v = input("Enter vertex: ")
            obj.addNode(v)

        elif n == 2:
            obj.addEdge_Undirected_Unweighted()

        elif n == 3:
            obj.addEdge_Undirected_weighted()

        elif n == 4:
            obj.addEdge_directed_weighted()

        elif n == 5:
            obj.printGraph()

        elif n == 6:
            obj.deletGraph()

        elif n == 0:
            print("Program terminated")
            sys.exit(0)

        else:
            print("Invalid choice"
# Out:
#   File "<tokenize>", line 72
#     if v not in self.nodes:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# GRAPH
import sys

class Graphs:

    def __init__(self):
        self.nodes = []
        self.graphs = []
        self.nodeCount = 0

    def addNode(self, v):

        if v in self.nodes:
            print(v, "node already exists")

        else:
            self.nodeCount += 1
            self.nodes.append(v)

            for x in self.graphs:
                x.append(0)

            temp = []

            for x in range(self.nodeCount):
                temp.append(0)

            self.graphs.append(temp)

            print(v, "is added")

    def addEdge_Undirected_Unweighted(self):

        v1 = input("Enter first vertex: ")
        v2 = input("Enter second vertex: ")

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")

        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = 1
            self.graphs[index2][index1] = 1

            print("Edge added successfully")

    def addEdge_Undirected_weighted(self):

        v1 = input("Enter first vertex: ")
        v2 = input("Enter second vertex: ")
        w = int(input("Enter weight: "))

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")

        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = w
            self.graphs[index2][index1] = w

            print("Undirected weighted edge added")

    def addEdge_directed_weighted(self):

        v1 = input("Enter source vertex: ")
        v2 = input("Enter destination vertex: ")
        w = int(input("Enter weight: "))

        if v1 not in self.nodes or v2 not in self.nodes:
            print("One or both vertices not found")

        else:
            index1 = self.nodes.index(v1)
            index2 = self.nodes.index(v2)

            self.graphs[index1][index2] = w

            print("Directed weighted edge added")

    def deleteGraph(self, v):

        if v not in self.nodes:
            print(v, "not present")

        else:
            self.nodeCount -= 1

            index1 = self.nodes.index(v)

            self.nodes.pop(index1)
            self.graphs.pop(index1)

            for x in self.graphs:
                x.pop(index1)

            print(v, "deleted")

    def printGraph(self):

        print("\nAdjacency Matrix:")

        print("   ", end="")

        for node in self.nodes:
            print(node, end=" ")

        print()

        for i in range(self.nodeCount):

            print(self.nodes[i], end="  ")

            for j in range(self.nodeCount):
                print(self.graphs[i][j], end=" ")

            print()


if __name__ == "__main__":

    obj = Graphs()

    while True:

        print("\n========== GRAPH MENU ==========")
        print("1. Add Node")
        print("2. Add Edge (Undirected Unweighted)")
        print("3. Add Edge (Undirected Weighted)")
        print("4. Add Edge (Directed Weighted)")
        print("5. Print Graph")
        print("6. Delete Vertex")
        print("0. Exit")

        n = int(input("Enter your choice: "))

        if n == 1:

            v = input("Enter vertex: ")
            obj.addNode(v)

        elif n == 2:

            obj.addEdge_Undirected_Unweighted()

        elif n == 3:

            obj.addEdge_Undirected_weighted()

        elif n == 4:

            obj.addEdge_directed_weighted()

        elif n == 5:

            obj.printGraph()

        elif n == 6:

            v = input("Enter vertex to delete: ")
            obj.deleteGraph(v)

        elif n == 0:

            print("Program terminated")
            sys.exit(0)

        else:

            print("Invalid choice")
# Out:
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Vertex
# 0. Exit
# A is added
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Vertex
# 0. Exit
# B is added
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Vertex
# 0. Exit
# C is added
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Vertex
# 0. Exit
# Edge added successfully
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Vertex
# 0. Exit
# Undirected weighted edge added
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Vertex
# 0. Exit
#
# Adjacency Matrix:
#    A B C
# A  0 1 0
# B  1 0 5
# C  0 5 0
#
# ========== GRAPH MENU ==========
# 1. Add Node
# 2. Add Edge (Undirected Unweighted)
# 3. Add Edge (Undirected Weighted)
# 4. Add Edge (Directed Weighted)
# 5. Print Graph
# 6. Delete Vertex
# 0. Exit

# %%
from IPython.core.application import IPYTHON_SUPPRESS_CONFIG_ERRORS
from IPython.core.application import IPYTHON_SUPPRESS_CONFIG_ERRORS
from IPython.core.application import IPYTHON_SUPPRESS_CONFIG_ERRORS
class A:
  def showA(self):
    print("I am in class A")
    class b(4):
      def showB(self):
        print("I am in class b")
        if __name__ == "__main__":

    obj = B()
    obj.showA()
    obj.showB()

# %%
from re import A
class A:
  def showA(self):
    print("I am in class A")
    class b(4):
      def showB(self):
        print("I am in class B")
        def showB(self):
        print("I am in class c")



        if __name__ == "__main__":

    obj = B()
    obj.showA()
    obj.showB()
    obj.showc()

# %%
def add(a):
  print(a)
  def add(a,b):
    print(a+b)
    def add()

# %%
sem = int(input("Enter no of semester: "))

for i in range(1, sem + 1):
    sub = int(input(f"Enter no of subjects in {i} semester: "))

    max_mark = -1

    print(f"Marks obtained in semester {i}:")

    for j in range(sub):
        mark = int(input())

        if mark < 0 or mark > 100:
            print("You have entered invalid mark.")
            exit()

        if mark > max_mark:
            max_mark = mark

    print(f"Maximum mark in {i} semester:{max_mark}")
# Out:
# Enter no of semester: 3
# Enter no of subjects in 1 semester: 3
# Marks obtained in semester 1:
# 50
# 60
# 70
# Maximum mark in 1 semester:70
# Enter no of subjects in 2 semester: 4
# Marks obtained in semester 2:
# 90
# 98
# 76
# 67
# Maximum mark in 2 semester:98
# Enter no of subjects in 3 semester: 2
# Marks obtained in semester 3:
# 89
# 76
# Maximum mark in 3 semester:89
