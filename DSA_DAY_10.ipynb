# %% [markdown]
# <a href="https://colab.research.google.com/github/PranaliIthule/DSA-Python-Training/blob/main/DSA_DAY_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python Implementation
class HashTable:
  def __init__(self,size):
    self.size=size
#self.table=[[]for i in range(size)]
    self.table=[]
    for i in range(size):
      self.table.append([])
  def hash_fanction(self,key):
    return key % self.size
  def insert(self,key=35):
    index=self.hash_fanction(key)
    self.table[index].append(key)
  def display(self):
    for x in range(10):
      print(self.table[x])

h=HashTable(10)
h.insert(25)
h.insert(35)
h.display()
# Out:
# []
# []
# []
# []
# []
# [25, 35]
# []
# []
# []
# []

# %%
from typing import Sized
class linnearProbing:
  def __init__(self,size):
    self.size=size
    self.table=[None]*self.size
  def hash_fanction(self,key):
    return key % self.size
  def insert(self,key):
    index = self.hash_fanction(key)
    while self.table[index] is not None:
      index = (index + 1) % self.size # Linear probing, wrap around if needed
    self.table[index] = key # Assign the key to the found slot

# %%
# Build Hash Table Manually

class MyHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size)]

    def hash_function(self, key):
        return key % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        self.table[index].append((key, value))

    def search(self, key):
        index = self.hash_function(key)
        for k, v in self.table[index]:
            if k == key:
                return v
        return "Not Found"

    def delete(self, key):
        index = self.hash_function(key)
        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                del self.table[index][i]
                return

    def display(self):
        print(self.table)

h=MyHashTable(10)
h.insert(1,"pranali")
h.insert(11,"sonakshi")
print(h.search(11))
h.display()
h.delete(1)
h.display()
# Out:
# sonakshi
# [[], [(1, 'pranali'), (11, 'sonakshi')], [], [], [], [], [], [], [], []]
# [[], [(11, 'sonakshi')], [], [], [], [], [], [], [], []]

# %%
import re

count = 0
pattern = re.compile("ab")
matcher = pattern.finditer("abaababaaab")

for match in matcher:
    count += 1
    print(match.start(), '...', match.end(), '...', match.group())

print("total no of group occurrences : ", count)
# Out:
# 0 ... 2 ... ab
# 3 ... 5 ... ab
# 5 ... 7 ... ab
# 9 ... 11 ... ab
# total no of group occurrences :  4

# %%
import re

count = 0
pattern = re.compile("aa")
matcher = pattern.finditer("abaababaaab")

for match in matcher:
    count += 1
    print(match.start(), "...", match.end(), "...", match.group())

print("total no of occurrences :", count)
# Out:
# 2 ... 4 ... aa
# 7 ... 9 ... aa
# total no of occurrences : 2

# %%
import re


x = "[abc]"
x = "[^abc]"
x = "[a-z]"
x = "[0-9]"
x = "[a-zA-Z0-9]"
x = "[^a-zA-Z0-9]"

matcher = re.finditer(x, "a7bd20@k2$D8z")

for match in matcher:
    print(match.start(), '...', match.group())
# Out:
# 6 ... @
# 9 ... $

# %%
import re



x = "\s"
x = "\S"
x = "\d"
x = "\D"
x = "\w"
x = "\W"

matcher = re.finditer(x, "a7b D 20@k20Bz")

for match in matcher:
    print(match.start(), '---', match.group())
# Out:
# 3 ---
# 5 ---
# 8 --- @
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\S'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\S'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# /tmp/ipykernel_10287/3080203432.py:5: SyntaxWarning: invalid escape sequence '\s'
#   x = "\s"
# /tmp/ipykernel_10287/3080203432.py:6: SyntaxWarning: invalid escape sequence '\S'
#   x = "\S"
# /tmp/ipykernel_10287/3080203432.py:7: SyntaxWarning: invalid escape sequence '\d'
#   x = "\d"
# ...

# %%
# number of a's
import re

x = "a"
x = "a*"
x = "a+"
x = "a?"
x = "a{3}"
x = "a{2,3}"

matcher = re.finditer(x, "abaabababaabaabaaaa")

for match in matcher:
    print(match.start(), '...', match.group())
# Out:
# 2 ... aa
# 9 ... aa
# 12 ... aa
# 15 ... aaa

# %%
import re

string = input("Enter any string : ")
m = re.match(string, 'abc@xyz_pqr')

if m is not None:
    print("Yes matching is available at beginning")
    print('start index:', m.start(), ' end index:', m.end())
else:
    print("matching is not available at beginning")
# Out:
# Enter any string : a
# Yes matching is available at beginning
# start index: 0  end index: 1

# %%
import re

string = input("Enter any string : ")
m = re.fullmatch(string, 'abc@xyz_pqr')

if m is not None:
    print("Yes matching is available at beginning")
    print('start index:', m.start(), ' end index:', m.end())
else:
    print("matching is not available at beginning")
# Out:
# Enter any string : abc@xyz_pqr
# Yes matching is available at beginning
# start index: 0  end index: 11

# %%
# findall(): To find all occurrences of the match.

import re

lst = re.findall("[0-9]", "ab4nhf7p@sqr9")
print(lst)

for x in lst:
    print(x)
# Out:
# ['4', '7', '9']
# 4
# 7
# 9

# %%
import re

result = re.sub('[a-z]', '$', 'abfa@4bc_v$8bz')
print(result)
print(type(result))
# Out:
# $$$$@4$$_$$8$$
# <class 'str'>

# %%
import re

number = input("Enter mobile number: ")
match = re.fullmatch("[6-9]\d{9}", number)

if match:
    print(number, "is valid mobile number")
else:
    print(number, "is not valid mobile number")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_10287/4167592688.py:4: SyntaxWarning: invalid escape sequence '\d'
#   match = re.fullmatch("[6-9]\d{9}", number)
# Enter mobile number: 9863267988
# 9863267988 is valid mobile number
