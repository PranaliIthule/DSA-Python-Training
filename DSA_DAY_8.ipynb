# %% [markdown]
# <a href="https://colab.research.google.com/github/PranaliIthule/DSA-Python-Training/blob/main/DSA_DAY_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
class BST:
  def insert(self):
    pass
    def preorder(self):
      pass
      def postorder(self):
         pass
    def inorder(self):
      pass
      if _name_=='_main_':
        root=BST()
        while True:
          print("1.Insret")
          print("2.preorder")
          print("3.postorder")
          print("4.inorder")
          print("0.Exit")
          n=int(input("select any choice:"))
          if n==1:
            root.insert()
            elif n==2:
# Out:
#   File "/tmp/ipykernel_5601/2320944726.py", line 22
#     elif n==2:
#     ^
# SyntaxError: invalid syntax

# %%
class BST:
    def __init__(self, key):
        self.leftChild = None
        self.data = key
        self.rightChild = None

    def insert(self, key):
        if self.data is None:
            self.data = key
            return

        elif self.data == key:
            return

        else:
            if key < self.data:
                if self.leftChild:
                    self.leftChild.insert(key)
                else:
                    self.leftChild = BST(key)

            else:
                if self.rightChild:
                    self.rightChild.insert(key)
                else:
                    self.rightChild = BST(key)

    def preorder(self):
        print(self.data, end=" -> ")

        if self.leftChild:
            self.leftChild.preorder()

        if self.rightChild:
            self.rightChild.preorder()
root = BST(50)
root.insert(30)
root.insert(20)
root.insert(40)
root.insert(70)
root.insert(60)
root.insert(80)

print("Preorder Traversal:")
root.preorder()
# Out:
# Preorder Traversal:
# 50 -> 30 -> 20 -> 40 -> 70 -> 60 -> 80 ->

# %%
import sys
class bst:
    def __init__(self, key):
        self.leftchild = None
        self.data = key
        self.rightchild = None

    def insert(self, key):
        if key < self.data:
            if self.leftchild:
                self.leftchild.insert(key)
            else:
                self.leftchild = bst(key)

        elif key > self.data:
            if self.rightchild:
                self.rightchild.insert(key)
            else:
                self.rightchild = bst(key)

    def preorder(self):
        print(self.data, end=" -> ")
        if self.leftchild:
            self.leftchild.preorder()
        if self.rightchild:
            self.rightchild.preorder()

    def inorder(self):
        if self.leftchild:
            self.leftchild.inorder()
        print(self.data, end=" -> ")
        if self.rightchild:
            self.rightchild.inorder()

    def postorder(self):
        if self.leftchild:
            self.leftchild.postorder()
        if self.rightchild:
            self.rightchild.postorder()
        print(self.data, end=" -> ")


if __name__ == '__main__':
    arr = [36, 26, 21, 31, 11, 24, 41, 56, 51, 66]
    root = bst(arr[0])
    for i in range(1, len(arr)):
        root.insert(arr[i])
    while True:
        print("\n1.Insert")
        print("2.Preorder")
        print("3.Inorder")
        print("4.Postorder")
        print("0.Exit")

        n = int(input("Select any choice: "))

        if n == 1:
            data = int(input("Enter value: "))
            root.insert(data)

        elif n == 2:
            root.preorder()
            print()

        elif n == 3:
            root.inorder()
            print()

        elif n == 4:
            root.postorder()
            print()

        elif n == 0:
            sys.exit()

        else:
            print("Invalid choice!")
# Out:
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 0.Exit
# 11 -> 21 -> 24 -> 26 -> 31 -> 36 -> 41 -> 51 -> 56 -> 66 ->
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 0.Exit
# 36 -> 26 -> 21 -> 11 -> 24 -> 31 -> 41 -> 56 -> 51 -> 66 ->
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 0.Exit
# 11 -> 24 -> 21 -> 31 -> 26 -> 51 -> 66 -> 56 -> 41 -> 36 ->
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 0.Exit

# %%
import sys

class bst:
    def __init__(self, key):
        self.leftchild = None
        self.data = key
        self.rightchild = None

    def insert(self, key):
        if key < self.data:
            if self.leftchild:
                self.leftchild.insert(key)
            else:
                self.leftchild = bst(key)

        elif key > self.data:
            if self.rightchild:
                self.rightchild.insert(key)
            else:
                self.rightchild = bst(key)

    def preorder(self):
        print(self.data, end=" -> ")
        if self.leftchild:
            self.leftchild.preorder()
        if self.rightchild:
            self.rightchild.preorder()

    def inorder(self):
        if self.leftchild:
            self.leftchild.inorder()
        print(self.data, end=" -> ")
        if self.rightchild:
            self.rightchild.inorder()

    def postorder(self):
        if self.leftchild:
            self.leftchild.postorder()
        if self.rightchild:
            self.rightchild.postorder()
        print(self.data, end=" -> ")

    def search(self, key):
        if self.data == key:
            print("Node found")
            return

        if key < self.data:
            if self.leftchild:
                self.leftchild.search(key)
            else:
                print("Node not found")
        else:
            if self.rightchild:
                self.rightchild.search(key)
            else:
                print("Node not found")


if __name__ == '__main__':
    arr = [36, 26, 21, 31, 11, 24, 41, 56, 51, 66]
    root = bst(arr[0])

    for i in range(1, len(arr)):
        root.insert(arr[i])

    while True:
        print("\n1.Insert")
        print("2.Preorder")
        print("3.Inorder")
        print("4.Postorder")
        print("5.Search")
        print("0.Exit")

        n = int(input("Select any choice: "))

        if n == 1:
            data = int(input("Enter value: "))
            root.insert(data)

        elif n == 2:
            root.preorder()
            print()

        elif n == 3:
            root.inorder()
            print()

        elif n == 4:
            root.postorder()
            print()

        elif n == 5:
            key = int(input("Enter value to search: "))
            root.search(key)

        elif n == 0:
            sys.exit()

        else:
            print("Invalid choice!")
# Out:
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 5.Search
# 0.Exit
# Node found
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 5.Search
# 0.Exit
# Node not found
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 5.Search
# 0.Exit
# 11 -> 24 -> 21 -> 31 -> 26 -> 51 -> 66 -> 56 -> 41 -> 36 ->
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 5.Search
# 0.Exit
# 36 -> 26 -> 21 -> 11 -> 24 -> 31 -> 41 -> 56 -> 51 -> 66 ->
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 5.Search
# 0.Exit
# 11 -> 21 -> 24 -> 26 -> 31 -> 36 -> 41 -> 51 -> 56 -> 66 ->
#
# 1.Insert
# 2.Preorder
# 3.Inorder
# 4.Postorder
# 5.Search
# 0.Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7443/2080633637.py in <cell line: 0>()
#      73         print("0.Exit")
#      74
# ---> 75         n = int(input("Select any choice: "))
#      76
#      77         if n == 1:
#
# ...

# %%
def fact(n=1):
    if n == 0 or n == 1:
        return 1
    else:
        return n * fact(n - 1)


if _name_ == '_main_':
    n = 5
    res = fact(n)
    print(res)

# %%
def power(x, y):
    if y == 0:
        return 1
    else:
        return x * power(x, y - 1)

if __name__ == "__main__":
    x = int(input("Enter base: "))
    y = int(input("Enter power: "))
    print("Result =", power(x, y))
# Out:
# Enter base: 4
# Enter power: 3
# Result = 64

# %%
def power(x, y):
    if y == 0:
        return 1
    else:
        return x * power(x, y - 1)
        if _name_ == "_main_":
          print(power(2, 3))

# %%
def sum_n(n):
    if n == 0:
        return 0
    else:
        return n + sum_n(n - 1)
        if _name_ == "_main_":
          print(sum_n(5))

# %%
from itertools import permutations


a, b = map(int, input().split())

digits = str(a)
ans = []


for p in permutations(digits):
    num = int(''.join(p))


    if num > b:
        ans.append(num)


if ans:
    print(min(ans))
else:
    print(-1)
# Out:
# 459 500
# 549

# %%
from itertools import permutations

a, b = map(int, input().split())

l = list(str(a))
ans = []

for i in permutations(l):
    num = int(''.join(i))
    if num > b:
        ans.append(num)

if len(ans) > 0:
    print(min(ans))
else:
    print(-1)
# Out:
# 459 500
# 549
