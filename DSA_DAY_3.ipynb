# %% [markdown]
# <a href="https://colab.research.google.com/github/PranaliIthule/DSA-Python-Training/blob/main/DSA_DAY_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add():
  a=int(input("enter a:"))
  b=int(input("enter b:"))
  res=a+b
  print("Addition is",res)
if __name__=='__main__':
  add()
# Out:
# enter a:67
# enter b:56
# Addition is 123

# %%
def add(a,b):
  res=a+b
  print("Addition is",res)
if __name__=='__main__':
  a=int(input("enter a:"))
  b=int(input("enter b:"))
  add(a,b)
# Out:
# enter a:45
# enter b:56
# Addition is 101

# %%
#function with parameter with return
def add(a,b):
  res=a+b
  return res

if __name__=='__main__':
  a=int(input("enter a:"))
  b=int(input("enter b:"))
  r=add(a,b)
  print("Addition is",r)
# Out:
# enter a:20
# enter b:12
# Addition is 32

# %%
def add(a,b):
  res1=a+b
  res2=a-b
  res3=a*b
  return res1,res2,res3

if __name__=='__main__':
  a=int(input("enter a:"))
  b=int(input("enter b:"))
  r1,r2,r3=add(a,b)
  print("Addition is",r1)
  print("sub is",r2)
  print("mul is",r3)
# Out:
# enter a:23
# enter b:20
# Addition is 43
# sub is 3
# mul is 460

# %%
def linear_search():
  pass
  if _name_=="_main_":
    n=int(input("enter size:")
    arr=list(map(int,input("enter elements":).split()))
    target=int(input("enter target":))

          if key in arr:
          print("element successfully found")
          else:
          print("element not found")
         if _name_=="_main_":
    n=int(input("enter size:")
    arr=list(map(int,input("en")))

# %%
def linear_Search(n,arr,target):
  flag=false
  for i in range(n):
    if target!=arr[i]:
      pass:
      flag=true
      loc=i
      if flag==true:
        print("search is successful and present at",loc)
        else:
          print("search is unsuccessful")

# %%
def binary_search(n, arr,target):
  flag=false
  low=0
  high=n-1
  while low<=high:
    mid=(low+high)//2
    if target==arr[mid]:
      flag=true
      loc=mid
      break;
      elif target<arr[mid]:
        if flag==true:
          print("search is succeful")
          else:
            print("search is unsucceful" ")
