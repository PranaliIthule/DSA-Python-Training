# %% [markdown]
# <a href="https://colab.research.google.com/github/PranaliIthule/DSA-Python-Training/blob/main/DSA_DAY_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#merge short
class mergeSorts:
    def mergeSort(self,arr1,arr2):
        arr3=[]
        i=0
        j=0
        k=0
        while i<len(arr1) and j<len(arr2):
            if arr1[i]<arr2[j]:
                arr3.aapend(arr1[i])
                i+=1
                k+=1
            else:
                arr3.append(arr2[j])
                j+=1
                k+=1

                return arr3

            if _name_ == 'main__':
                obj=self.mergeSorts()
                arr1=[1,3,5]
                arr2=[2,4,6]
                ans=obj.mergeSorts(arr1,arr2)
                print(ans)

# %%
class mergeSorts:
    def mergeSort(self,arr1,arr2):
        arr3=[]
        i=0
        j=0
        k=0
        while i<len(arr1) and j<len(arr2):
            if arr1[i]<arr2[j]:
                arr3.append(arr1[i])
                i+=1
                k+=1
            else:
                arr3.append(arr2[j])
                j+=1
                k+=1
        return arr3

if __name__ == '__main__':
    obj=mergeSorts()
    arr1=[1,3,5]
    arr2=[2,4,6]
    ans=obj.mergeSort(arr1,arr2)
    print(*ans,sep="")
# Out:
# 12345

# %%
#
class mergeSorts:
    def mergeSort(self, arr):
        if len(arr) <= 1:
            return arr

        mid = len(arr) // 2
        left = self.mergeSort(arr[:mid])
        right = self.mergeSort(arr[mid:])
        return self.merge(left, right)

    def merge(self, arr1, arr2):
        arr3 = []
        i = 0
        j = 0

        while i < len(arr1) and j < len(arr2):
            if arr1[i] < arr2[j]:
                arr3.append(arr1[i])
                i += 1
            else:
                arr3.append(arr2[j])
                j += 1

        while i < len(arr1):
            arr3.append(arr1[i])
            i += 1

        while j < len(arr2):
            arr3.append(arr2[j])
            j += 1

        return arr3


if __name__ == '__main__':
    obj = mergeSorts()
    arr = [1, 3, 5, 2, 4, 6]
    ans = obj.mergeSort(arr)
    print(*ans, sep="")
# Out:
# 123456

# %%
class mergeSorts:
    def mergeSort(self, arr):
        if len(arr) <= 1:
            return arr

        mid = len(arr) // 2
        arr1 = self.mergeSort(arr[:mid])
        arr2 = self.mergeSort(arr[mid:])

        arr3 = []
        i = 0
        j = 0

        while i < len(arr1) and j < len(arr2):
            if arr1[i] < arr2[j]:
                arr3.append(arr1[i])
                i += 1
            else:
                arr3.append(arr2[j])
                j += 1

        while i < len(arr1):
            arr3.append(arr1[i])
            i += 1

        while j < len(arr2):
            arr3.append(arr2[j])
            j += 1

        return arr3


if __name__ == '__main__':
    obj = mergeSorts()
    arr = [6, 3, 8, 2, 5, 1, 4]
    ans = obj.mergeSort(arr)
    print(*ans)
# Out:
# 1 2 3 4 5 6 8

# %%
class MergeSorts:

    def mergeSort(self, arr):
        if len(arr) > 1:

            mid = len(arr) // 2

            arr1 = arr[:mid]
            arr2 = arr[mid:]


            self.mergeSort(arr1)
            self.mergeSort(arr2)

            i = 0
            j = 0
            k = 0


            while i < len(arr1) and j < len(arr2):
                if arr1[i] < arr2[j]:
                    arr[k] = arr1[i]
                    i += 1
                else:
                    arr[k] = arr2[j]
                    j += 1
                k += 1


            while i < len(arr1):
                arr[k] = arr1[i]
                i += 1
                k += 1


            while j < len(arr2):
                arr[k] = arr2[j]
                j += 1
                k += 1


if __name__ == "__main__":
    obj = MergeSorts()
    arr = [1, 7, 12, 3, 6, 2, 9]
    obj.mergeSort(arr)
    print(arr)
# Out:
# [1, 2, 3, 6, 7, 9, 12]

# %%
def append(self):
  date=int(input("Enter data:"))
  newNode=GetNode()
  newnode data=data
  if self.head=newNode
  else:
    ptr=self.head
    while ptr.next!=None:
      ptr.Next=newNode
      prit(data,"is added")
      def traverse(self):
        if self.head=none:
          print("linked List not Present")
        else:
            ptr=self.head
            while ptr!=None:
              print(ptr,data,"->"",end")
              ptr=ptr,next
              if_name_==
              "_main_":
              obj=LinkedList()
              while true:
                print(1.append)
                print(2.traverse)

# %%
class Parent:

    def __init__(self):
        self.speed = 100
        print("Cash, Gold")

    def bike(self):
        print("Splender+ :", self.speed)


class Child(Parent):

    def __init__(self):
        super().__init__()
        self.speed = 150

    def bike(self):
        print("HB :", self.speed)


# Main
if __name__ == "__main__":

    obj = Child()

    obj.bike()
# Out:
# Cash, Gold
# HB : 150
